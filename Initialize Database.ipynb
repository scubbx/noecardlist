# %% [markdown]
# Extract the list of all possible locations as a bulk from www.niederoesterreich-card.at/alle-ausflugsziele/0 up to www.niederoesterreich-card.at/alle-ausflugsziele/27 with http://import.io (https://import.io/data/mine/?id=57367c6e-1454-43b8-8f08-01780ca79aef)

# %%
import csv
import mpcouch
from lxml import html
import requests
import couchdb
import hashlib

import requests

couchdbUrl = "http://gi88.geoinfo.tuwien.ac.at:5984"

# %% [markdown]
# First, we collect the data from the CSV file in a list. We could already perform the collection of data here, but since there are only about 334 entries, there is no measurable loss in speed.

# %%
collectedDocs = []
with open('noeHomepageData_2016.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",", quotechar='"')
    for i, row in enumerate(csvreader):
        if i == 0: continue
        pushDoc = {'title': row[14],
                   'link': row[9],
                   'category': row[13],
                   'plz': row[15],
                   'addr': row[11],
                   'imageUrl': row[2]}
        collectedDocs.append(pushDoc)
        #couchPusher.pushData(pushDoc)
    #couchPusher.finish()
print("Collected entries: {}".format(len(collectedDocs)))
# Out:
# Collected entries: 322

# %% [markdown]
# Now, we collect the missing information by calling each website of each entry and parsing it. After that it gets uploaded to the CouchDB database.
# One important thing is, that we calculate a hash value of every entry important, so we can detect any real change in comparison to the data already in the database. When this check is performed on the mobile end-point, every user acts as a updating node automatically. So, in reality, all we would have to do manually, is to check whether any entries are added or removed.
#
# The **contentHash** contains a hash value for the **description**, the **price** and the **opening hours**.

# %%
couchPusher = mpcouch.mpcouchPusher(couchdbUrl+"/noecard2016", 10000)
for i, entry in enumerate(collectedDocs):
    print("processing entry {} of {}: {}".format(i, len(collectedDocs), entry['title']))
    page = requests.get(entry['link'])
    pageTree = html.fromstring(page.content)
    errorText = pageTree.xpath('//*[@id="body"]/div[2]/div/section/article/p[1]/strong')
    if len(errorText) < 1:
        pageDescription = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/article/div/p[1]')[0].text
        pagePrice = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[2]/p/span[2]')[0].text
        pageOpen = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[4]/p[2]')[0].text
        pageLocation = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[3]/p[2]/span[3]')[0].text
        pageLocationName = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[3]/p[1]/strong')[0]

        try:
            pageMapString = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[5]/figure/img/@src')[0]
            pageMap = pageMapString.replace('7C','').replace('2C','').split('%')
            pageMap = [pageMap[-1], pageMap[-2]]
        except IndexError:
            pageMap = []
        
        collectedDocs[i]['_id'] = collectedDocs[i]['title'].replace(" ", "") # lets make all IDs lowercase for JS compatibility
        collectedDocs[i]['description'] = pageDescription
        collectedDocs[i]['price'] = float(pagePrice.replace('€ ','').replace('â\x82¬ ','').replace(',','.'))
        collectedDocs[i]['open'] = pageOpen
        collectedDocs[i]['coordinates'] = pageMap
        
        collectedDocs[i]['entryId'] = i
        
        if pageOpen == None: pageOpen = ""
        if pageDescription == None: pageDescription = ""
        if pagePrice == None: pagePrice = ""  
            
        hashString = (pageDescription+pagePrice+pageOpen).encode('utf-8')
        collectedDocs[i]['contentHash'] = hashlib.sha1(hashString).hexdigest()
        
        couchPusher.pushData(collectedDocs[i])
    else:
        # the page does not exist anymore, ignore
        pass
couchPusher.finish()
# Out:
# processing entry 0 of 322: Stift Altenburg
# processing entry 1 of 322: BÄRENWALD
# processing entry 2 of 322: Hammerschmiede Kamp
# processing entry 3 of 322: Mohndorf Armschlag
# processing entry 4 of 322: Schloss Artstetten
# processing entry 5 of 322: Schnaps-Glas-Museum Echsenbach
# processing entry 6 of 322: Erlebnis-Freibad
# processing entry 7 of 322: Krahuletz-Museum
# processing entry 8 of 322: Nostalgiewelt Eggenburg
# processing entry 9 of 322: Perlmuttmanufaktur
# processing entry 10 of 322: NÖ Falknerei- und Greifvogelzentrum
# processing entry 11 of 322: WALDLAND
# processing entry 12 of 322: Wirtex – Älteste Frottierweberei
# processing entry 13 of 322: Naturpark Geras
# processing entry 14 of 322: Stift Geras
# processing entry 15 of 322: Naturpark Blockheide
# processing entry 16 of 322: Sole-Felsen-Bad
# processing entry 17 of 322: Waldviertelbahn
# processing entry 18 of 322: Schloss Grafenegg
# processing entry 19 of 322: SONNENWELT
# processing entry 20 of 322: Nationalpark Thayatal
# processing entry 21 of 322: Käsemacherwelt
# processing entry 22 of 322: Naturpark Heidenreichsteiner Moor
# processing entry 23 of 322: Museen der Stadt Horn
# processing entry 24 of 322: Ausstellungshaus Spoerri
# processing entry 25 of 322: Sport- und Erlebnisbad
# processing entry 26 of 322: Zeitbrücke-Museum
# processing entry 27 of 322: Miniaturgolfplatz
# processing entry 28 of 322: Freizeitmuseum Langau
# processing entry 29 of 322: Heimatmuseum Langenlois
# processing entry 30 of 322: LOISIUM - WeinErlebnisWelt
# processing entry 31 of 322: Landtechnikmuseum im Europaschloss Leiben
# processing entry 32 of 322: Disc Golf Herrensee
# processing entry 33 of 322: Golfclub Herrensee
# processing entry 34 of 322: Amethyst Welt Maissau
# processing entry 35 of 322: Märchenausstellung
# processing entry 36 of 322: Bäckereimuseum - Brodcafé
# processing entry 37 of 322: Waldviertler Mohnhof
# processing entry 38 of 322: Freibad Mandlgupf
# processing entry 39 of 322: Kunstglasbläserei
# processing entry 40 of 322: Schidorf Kirchbach
# processing entry 41 of 322: Hanfdorf Reingers
# processing entry 42 of 322: Whisky-Erlebniswelt, Destillerie Haider
# processing entry 43 of 322: Renaissanceschloss Greillenstein
# processing entry 44 of 322: Kittenberger Erlebnisgärten
# processing entry 45 of 322: ANWO Schaugarten
# processing entry 46 of 322: Österreichisches Freimaurermuseum
# processing entry 47 of 322: Das Kunstmuseum Waldviertel
# processing entry 48 of 322: Schätze der Vergangenheit
# processing entry 49 of 322: UnterWasserReich
# processing entry 50 of 322: Waldviertler Schuhwerkstatt
# processing entry 51 of 322: Waldviertler Erdäpfelwelt
# processing entry 221 of 322: Arnulf Rainer Museum
# processing entry 222 of 322: Puppen- und Spielzeugmuseum
# processing entry 223 of 322: Badener Trabrennverein
# processing entry 224 of 322: Beethovenhaus Baden
# processing entry 225 of 322: Kaiser-Franz-Josef-Museum
# processing entry 226 of 322: Kaiserhaus Baden
# processing entry 227 of 322: Rollettmuseum
# processing entry 228 of 322: Römertherme Baden
# processing entry 229 of 322: krupp stadt museum BERNDORF
# processing entry 230 of 322: Freibad der Marktgemeinde Gumpoldskirchen
# processing entry 231 of 322: Freigut Thallern
# processing entry 232 of 322: Gumpoldskirchner Weinbaumuseum
# processing entry 233 of 322: Seegrotte Hinterbrühl
# processing entry 234 of 322: Die Kletterei – Kletterzentrum
# processing entry 235 of 322: Schlosspark Laxenburg
# processing entry 236 of 322: LEUM - Lichtmuseum & mehr
# processing entry 237 of 322: Minigolfclub Leobersdorf
# processing entry 238 of 322: Wellnessoase Leobersdorf
# processing entry 239 of 322: Kletterhalle Südstadt
# processing entry 240 of 322: Kartause Mauerbach
# processing entry 241 of 322: Museum Mödling – Thonetschlössl
# processing entry 242 of 322: Rocktopia – die Kletterhalle
# processing entry 243 of 322: Volkskundemuseum Mödling
# processing entry 244 of 322: Freizeitzentrum Perchtoldsdorf
# processing entry 245 of 322: Naturpark Sparbach
# processing entry 246 of 322: Stadtmuseum Traiskirchen
# processing entry 247 of 322: Farbie Kinderspielwelt
# processing entry 248 of 322: Vöslauer Mineralwasser AG
# processing entry 249 of 322: Stadtmuseum Bad Vöslau
# processing entry 250 of 322: Vöslauer Thermalbad
# processing entry 251 of 322: Glasmuseum „Die gläserne Burg“
# processing entry 252 of 322: Triestingtaler Heimatmuseum
# processing entry 253 of 322: Zisterzienserabtei Stift Heiligenkreuz
# processing entry 254 of 322: Fischauer Thermalbad
# processing entry 255 of 322: Burg Forchtenstein
# processing entry 256 of 322: Renner Museum für Zeitgeschichte
# processing entry 257 of 322: Waldbauernmuseum Gutenstein
# processing entry 258 of 322: Zinnfigurenwelt Katzelsdorf
# processing entry 259 of 322: Automobilmuseum
# processing entry 260 of 322: Freibad Aspang
# processing entry 261 of 322: Gauermann-Museum
# processing entry 262 of 322: Sessellift, Roller- u. Mountaincartbahn
# processing entry 263 of 322: Städtisches Museum
# processing entry 264 of 322: Waldbad Markt Piesting
# processing entry 265 of 322: Schlossbad Pitten
# processing entry 266 of 322: Rax-Seilbahn
# processing entry 267 of 322: Galerie und Atelier VOKA
# processing entry 268 of 322: Schneeberg Sesselbahn
# processing entry 269 of 322: Schneebergbahn
# processing entry 270 of 322: Schwimmbad Grünbach
# processing entry 271 of 322: Archäologisches Freilichtmuseum Schwarzenbach
# processing entry 272 of 322: Zauberberg Semmering
# processing entry 273 of 322: Hohe Wand Naturpark und Mautstraße
# processing entry 274 of 322: Familienschiland St. Corona
# processing entry 275 of 322: RAMSWIRT – schwerster Fleckviehzuchtstier
# processing entry 276 of 322: Sommerrodelbahn St. Corona
# processing entry 277 of 322: Wechsel-Semmering-Panoramaloipe
# processing entry 278 of 322: Burgbad Kirchschlag
# processing entry 279 of 322: Arena Nova-Indoor Golf
# processing entry 280 of 322: Stadtmuseum Wiener Neustadt
# processing entry 281 of 322: Würflacher WellnessWelt
# processing entry 282 of 322: 21er Haus
# processing entry 283 of 322: Donauturm
# processing entry 284 of 322: Haus der Musik - Das Klangmuseum
# processing entry 285 of 322: Heeresgeschichtliches Museum
# processing entry 286 of 322: Josephinum - Sammlung der Medizinischen Universität
# processing entry 287 of 322: Kaiserliche Wagenburg
# processing entry 288 of 322: Madame Tussauds Wien
# processing entry 289 of 322: Monki Park
# processing entry 290 of 322: MS Kaiserin Elisabeth II
# processing entry 291 of 322: Museum im Schottenstift
# processing entry 292 of 322: Österreichische Nationalbibliothek
# processing entry 293 of 322: Österreichisches Museum für Volkskunde
# processing entry 294 of 322: Porzellanmuseum im Augarten
# processing entry 295 of 322: Schlumberger Kellerwelten
# processing entry 296 of 322: SchokoMuseum
# processing entry 297 of 322: Schönbrunner Panoramabahn
# processing entry 298 of 322: Secession
# processing entry 299 of 322: Sigmund Freud Museum
# processing entry 300 of 322: Spanische Hofreitschule
# processing entry 301 of 322: Time Travel
# processing entry 302 of 322: UNO - Vereinte Nationen
# processing entry 303 of 322: Unteres Belvedere
# processing entry 304 of 322: Verkehrsmuseum der Wiener Linien
# processing entry 305 of 322: Vienna Ring Tram
# processing entry 306 of 322: VISITAIR Center – Faszination Flughafen
# processing entry 307 of 322: Wiener Riesenrad
# processing entry 308 of 322: Winterpalais des Prinzen Eugen von Savoyen
# processing entry 309 of 322: Wüstenhaus Schönbrunn
# processing entry 310 of 322: Schloss Esterházy
# processing entry 311 of 322: Reptilien Zoo
# processing entry 312 of 322: Freilichtmuseum Ensemble Gerersdorf
# processing entry 313 of 322: Schloss Halbturn
# processing entry 314 of 322: Schloss Lackenbach
# processing entry 315 of 322: Landtechnikmuseum Burgenland
# processing entry 316 of 322: Museum Arbeitswelt
# processing entry 317 of 322: bellabayer – das Gartenatelier
# processing entry 318 of 322: oekopark Hartberg
# processing entry 319 of 322: Stadtmuseum Hartberg
# processing entry 320 of 322: Lipizzanergestüt Piber
# processing entry 321 of 322: Mariazeller Bürgeralpe
# generate final upload process ...
# processcount: 1 process-queue: 0  collected so far: 322
# waiting for upload-process <Process(Process-1, started)> to finish ...
# 322

# %% [markdown]
# Now, we want to include the image of the entry. We have to perform this step in a second run, since with the CouchDB interface in Python, the document has to already exist, when an attachment is added to it.

# %%
couchdbserver = couchdb.Server(couchdbUrl)
couchdbdb = couchdbserver['noecard']

for i, entry in enumerate(collectedDocs):
    print("Retrieving {}: {}".format(i, entry['title']))
    currentDoc = couchdbdb.get(entry['title'])
    if currentDoc != None and currentDoc['imageUrl'] != '':
        response = requests.get(currentDoc['imageUrl'])
        storeName = "preview.jpg"
        couchdbdb.put_attachment(currentDoc, response.content, filename=storeName, content_type='image/jpeg')
