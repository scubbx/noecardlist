# %% [markdown]
# Extract the list of all possible locations as a bulk from www.niederoesterreich-card.at/alle-ausflugsziele/0 up to www.niederoesterreich-card.at/alle-ausflugsziele/27 with http://import.io (https://import.io/data/mine/?id=57367c6e-1454-43b8-8f08-01780ca79aef)

# %%
import csv
import mpcouch
from lxml import html
import requests
import couchdb
import hashlib

import requests

couchdbUrl = "http://gi88.geoinfo.tuwien.ac.at:5984"

# %% [markdown]
# First, we collect the data from the CSV file in a list. We could already perform the collection of data here, but since there are only about 334 entries, there is no measurable loss in speed.

# %%
collectedDocs = []
with open('noeHomepageData.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",", quotechar='"')
    for i, row in enumerate(csvreader):
        if i == 0: continue
        pushDoc = {'title': row[14],
                   'link': row[9],
                   'category': row[13],
                   'plz': row[15],
                   'addr': row[11],
                   'imageUrl': row[2]}
        collectedDocs.append(pushDoc)
        #couchPusher.pushData(pushDoc)
    #couchPusher.finish()
print("Collected entries: {}".format(len(collectedDocs)))
# Out:
# Collected entries: 333

# %% [markdown]
# Now, we collect the missing information by calling each website of each entry and parsing it. After that it gets uploaded to the CouchDB database.
# One important thing is, that we calculate a hash value of every entry important, so we can detect any real change in comparison to the data already in the database. When this check is performed on the mobile end-point, every user acts as a updating node automatically. So, in reality, all we would have to do manually, is to check whether any entries are added or removed.
#
# The **contentHash** contains a hash value for the **description**, the **price** and the **opening hours**.

# %%
couchPusher = mpcouch.mpcouchPusher(couchdbUrl+"/noecard", 10000)
for i, entry in enumerate(collectedDocs):
    print("processing entry {} of {}: {}".format(i, len(collectedDocs), entry['title']))
    page = requests.get(entry['link'])
    pageTree = html.fromstring(page.content)
    errorText = pageTree.xpath('//*[@id="body"]/div[2]/div/section/article/p[1]/strong')
    if len(errorText) < 1:
        pageDescription = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/article/div/p[1]')[0].text
        pagePrice = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[2]/p/span[2]')[0].text
        pageOpen = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[4]/p[2]')[0].text
        pageLocation = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[3]/p[2]/span[3]')[0].text
        pageLocationName = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[3]/p[1]/strong')[0]

        try:
            pageMapString = pageTree.xpath('//*[@id="detailArticleNOECard"]/div/section/aside/article[5]/figure/img/@src')[0]
            pageMap = pageMapString.replace('7C','').replace('2C','').split('%')
            pageMap = [pageMap[-1], pageMap[-2]]
        except IndexError:
            pageMap = []
        
        collectedDocs[i]['_id'] = collectedDocs[i]['title']
        collectedDocs[i]['description'] = pageDescription
        collectedDocs[i]['price'] = float(pagePrice.replace('€ ','').replace(',','.'))
        collectedDocs[i]['open'] = pageOpen
        collectedDocs[i]['coordinates'] = pageMap
        
        collectedDocs[i]['entryId'] = i
        
        if pageOpen == None: pageOpen = ""
        if pageDescription == None: pageDescription = ""
        if pagePrice == None: pagePrice = ""  
            
        hashString = (pageDescription+pagePrice+pageOpen).encode('utf-8')
        collectedDocs[i]['contentHash'] = hashlib.sha1(hashString).hexdigest()
        
        couchPusher.pushData(collectedDocs[i])
    else:
        # the page does not exist anymore, ignore
        pass
couchPusher.finish()
# Out:
# processing entry 0 of 333: Stift Altenburg
# processing entry 1 of 333: BÄRENWALD
# processing entry 2 of 333: Hammerschmiede Kamp
# processing entry 3 of 333: Mohndorf Armschlag
# processing entry 4 of 333: Schnaps-Glas-Museum Echsenbach
# processing entry 5 of 333: Krahuletz-Museum
# processing entry 6 of 333: Nostalgiewelt Eggenburg
# processing entry 7 of 333: Perlmuttdrechslerei
# processing entry 8 of 333: NÖ Falknerei- und Greifvogelzentrum
# processing entry 9 of 333: Wirtex – Älteste Frottierweberei
# processing entry 10 of 333: Naturpark Geras
# processing entry 11 of 333: Stift Geras
# processing entry 12 of 333: Naturpark Blockheide
# processing entry 13 of 333: Sole-Felsen-Bad
# processing entry 14 of 333: Waldviertelbahn
# processing entry 15 of 333: Schloss Grafenegg
# processing entry 16 of 333: SONNENWELT
# processing entry 17 of 333: Nationalpark Thayatal
# processing entry 18 of 333: Käsemacherwelt
# processing entry 19 of 333: Naturpark Heidenreichsteiner Moor
# processing entry 20 of 333: Museen der Stadt Horn Höbarth- und Madermuseum
# processing entry 21 of 333: Kindererlebniswelt MOKE
# processing entry 22 of 333: Sport- und Erlebnisbad Gars am Kamp
# processing entry 23 of 333: Zeitbrücke-Museum
# processing entry 24 of 333: Schidorf Kirchbach
# processing entry 25 of 333: Miniaturgolfplatz
# processing entry 26 of 333: Freizeitmuseum Langau
# processing entry 27 of 333: Heimatmuseum Langenlois
# processing entry 28 of 333: LOISIUM- WeinErlebnisWelt
# processing entry 29 of 333: Energiewelt „SIRIUS“
# processing entry 30 of 333: Golfclub Herrensee
# processing entry 31 of 333: Amethyst Welt Maissau
# processing entry 32 of 333: Edelsteinhaus Maissau
# processing entry 33 of 333: Märchenausstellung
# processing entry 34 of 333: Waldviertler Mohnhof
# processing entry 35 of 333: Freibad Mandlgupf
# processing entry 36 of 333: Kunstglasbläserei
# processing entry 37 of 333: Schloss Pöggstall
# processing entry 38 of 333: Hanfdorf Reingers
# processing entry 39 of 333: Museum Retz und Südmährische Galerie
# processing entry 40 of 333: Bahnerlebnis Reblaus Express
# processing entry 41 of 333: Windmühle Retz
# processing entry 42 of 333: Whisky-Erlebniswelt, Destillerie Haider
# processing entry 43 of 333: Renaissanceschloss Greillenstein
# processing entry 44 of 333: Kittenberger Erlebnisgärten
# processing entry 45 of 333: ANWO Schaugarten
# processing entry 46 of 333: Österreichisches Freimaurermuseum
# processing entry 47 of 333: Das Kunstmuseum Waldviertel
# processing entry 48 of 333: Schätze der Vergangenheit
# processing entry 49 of 333: UnterWasserReich
# processing entry 50 of 333: Waldviertler Schuhwerkstatt
# processing entry 51 of 333: Waldviertler Erdäpfelwelt
# processing entry 52 of 333: Kloster-Schul-Werkstätten & Museum Schönbach
# processing entry 53 of 333: Straußenland Gärtner
# processing entry 54 of 333: Freilichtmuseum Germanisches Gehöft Elsarn
# processing entry 55 of 333: Fassbinderei- und Weinbaumuseum
# processing entry 56 of 333: Schatzkammer der Basilika
# processing entry 57 of 333: Kräuterpfarrer-Weidinger-Zentrum
# processing entry 58 of 333: Ruine Kollmitz
# processing entry 59 of 333: Thayatal Vitalbad
# processing entry 60 of 333: Uhrenmuseum Karlstein
# processing entry 61 of 333: Ausstellungszentrum Josef Elter
# processing entry 62 of 333: Waldrapp Voliere
# processing entry 63 of 333: Sonnenuhren-Ausstellung Jindra
# processing entry 64 of 333: Brauerei im Brauhotel Weitra
# processing entry 65 of 333: Schloss Weitra
# processing entry 66 of 333: Hallenbad Yspertal
# processing entry 67 of 333: Zwettler Dämmerschoppen
# processing entry 68 of 333: SONNENTOR Erlebnis
# processing entry 69 of 333: Stadtmuseum Zwettl
# processing entry 70 of 333: Zisterzienserstift Zwettl
# processing entry 71 of 333: Kinderparadies Wirtshaus zur Minidampfbahn
# processing entry 72 of 333: ZwettlBad
# processing entry 73 of 333: Traktorium Drasenhofen
# processing entry 74 of 333: Erlebnis-Freibad Eggenburg
# processing entry 75 of 333: NostalgieExpress Leiser Berge
# processing entry 76 of 333: Erstes Österreichisches Küchenmuseum und Greisslereimuseum
# processing entry 77 of 333: Nonseum
# processing entry 78 of 333: Schloss Jedenspeigen
# processing entry 79 of 333: Der Heldenberg
# processing entry 80 of 333: LEMU - LANGENZERSDORF MUSEUM
# processing entry 81 of 333: Schloss Mailberg
# processing entry 82 of 333: Michelstettner Schule
# processing entry 83 of 333: MAMUZ MUSEUM Mistelbach
# processing entry 84 of 333: Zayataler Schienentaxi
# processing entry 85 of 333: Museumsdorf Niedersulz
# processing entry 86 of 333: Wehrturm
# processing entry 87 of 333: Steinzeitkeller
# processing entry 88 of 333: Oldtimermuseum Poysdorf
# processing entry 89 of 333: Vino Versum
# processing entry 90 of 333: Pulkauer Blutkirche
# processing entry 91 of 333: KLEINHAUS – Bio Weinbau Killmeyer
# processing entry 92 of 333: Fahrradmuseum Retz
# processing entry 93 of 333: Retzer Erlebniskeller
# processing entry 94 of 333: Perlen- und Fossilienwelt Weinviertel
# processing entry 95 of 333: STILLFRIED – Zentrum der Urzeit
# processing entry 96 of 333: Kutschenmuseum Laa
# processing entry 97 of 333: Liechtenstein-Schloss Wilfersdorf
# processing entry 98 of 333: Kunsteisbahn Wolkersdorf
# processing entry 99 of 333: Kletterhalle Nordwandklettern
# processing entry 100 of 333: Sommerbad Wolkersdorf
# processing entry 101 of 333: MAMUZ Schloss Asparn an der Zaya
# processing entry 102 of 333: Freibad Absdorf
# processing entry 103 of 333: Schloss Artstetten
# processing entry 104 of 333: Museum Carnuntinum
# processing entry 105 of 333: Kuenringer Freibad Dürnstein
# processing entry 106 of 333: Schloss Eckartsau
# processing entry 107 of 333: ERLAUF ERINNERT Museum der Friedensgemeinde Erlauf
# processing entry 108 of 333: Erlebnispark Gänserndorf
# processing entry 109 of 333: Benediktinerstift Göttweig
# processing entry 110 of 333: Bergbad
# processing entry 111 of 333: Stadtführung Mittelalterstadt
# processing entry 112 of 333: Aquapark Herzogenburg
# processing entry 113 of 333: Stift Herzogenburg
# processing entry 114 of 333: Happyland
# processing entry 115 of 333: Stift Klosterneuburg
# processing entry 116 of 333: Bahnengolfclub Wachau
# processing entry 117 of 333: BRANDNER Schiffahrt GmbH
# processing entry 118 of 333: Gozzoburg
# processing entry 119 of 333: Museum Krems
# processing entry 120 of 333: Weinerlebnis „Sandgrube 13 wein.sinn“ Winzer Krems
# processing entry 121 of 333: Wachaubahn
# processing entry 122 of 333: Zeit Kunst Niederösterreich
# processing entry 123 of 333: Parkbad Königstetten
# processing entry 124 of 333: Landtechnikmuseum im Europaschloss Leiben
# processing entry 125 of 333: VillaVinum
# processing entry 126 of 333: Schloss Marchegg
# processing entry 127 of 333: museum gugging
# processing entry 128 of 333: Römermuseum Mautern
# processing entry 129 of 333: DDSG Blue Danube Schiffahrt
# processing entry 130 of 333: Benediktinerstift Melk
# processing entry 131 of 333: Bäckereimuseum
# processing entry 132 of 333: museumORTH an der Donau
# processing entry 133 of 333: schlossORTH Nationalpark-Zentrum
# processing entry 134 of 333: Archäologischer Park Carnuntum
# processing entry 135 of 333: Oskar-Kokoschka-Dokumentation
# processing entry 136 of 333: Haydn-Geburtshaus Rohrau
# processing entry 137 of 333: Schloss Rohrau – Graf Harrach’sche Familiensammlung
# processing entry 138 of 333: Pleyel-Museum
# processing entry 139 of 333: Schloss Hof
# processing entry 140 of 333: Schloss Niederweiden
# processing entry 141 of 333: Eisenbahnmuseum Schwechat
# processing entry 142 of 333: Parkbad
# processing entry 143 of 333: Autofrei unterwegs in der Wachau
# processing entry 144 of 333: Schifffahrtsmuseum
# processing entry 145 of 333: Forum Frohner
# processing entry 146 of 333: Karikaturmuseum Krems
# processing entry 147 of 333: Kunsthalle Krems
# processing entry 148 of 333: Eisenbahnmuseum Strasshof
# processing entry 149 of 333: Aubad der Stadt Tulln
# processing entry 150 of 333: DIE GARTEN TULLN – Naturgarten Erlebniswelt Niederösterreich
# processing entry 151 of 333: Egon Schiele Museum
# processing entry 152 of 333: Donau Splash
# processing entry 153 of 333: Kunsteisbahn der Stadt Tulln
# processing entry 154 of 333: MS Stadt Wien - Nostalgieschiff
# processing entry 155 of 333: Römermuseum Tulln
# processing entry 156 of 333: Wachaumuseum
# processing entry 157 of 333: Donaukraftwerk
# processing entry 158 of 333: Annaberger Liftbetriebe
# processing entry 159 of 333: Wienerwaldmuseum und Lebendiges Handwerk
# processing entry 160 of 333: Freibad Frankenfels
# processing entry 161 of 333: Bergbauernmuseum Hausstein
# processing entry 162 of 333: Landesausstellung 2015: Frankenfels – Laubenbachmühle
# processing entry 163 of 333: Nixhöhle
# processing entry 164 of 333: Bruckners Bierwelt
# processing entry 165 of 333: Hallenbad und Sauna Gaming
# processing entry 166 of 333: Kartause Gaming
# processing entry 167 of 333: Ötscher Tropfsteinhöhle
# processing entry 168 of 333: Ötscherland Freibad Gaming
# processing entry 169 of 333: Tierpark Stadt Haag
# processing entry 170 of 333: Abenteuerland Pielachtal
# processing entry 171 of 333: PIELACHTALER sehnsucht
# processing entry 172 of 333: Voralpenbad Hohenberg
# processing entry 173 of 333: Kornkreismuseum
# processing entry 174 of 333: Ötscherlifte
# processing entry 175 of 333: Sessellift Lilienfeld Muckenkogel
# processing entry 176 of 333: Stift Lilienfeld
# processing entry 177 of 333: Renaissanceschloss Schallaburg
# processing entry 178 of 333: Bergbahnen Mitterbach
# processing entry 179 of 333: Freibad Neulengbach
# processing entry 180 of 333: World of STYX
# processing entry 181 of 333: HAUBIVERSUM – „Die Backerlebniswelt“
# processing entry 182 of 333: Erlebnisfreibad Kirchberg an der Pielach
# processing entry 183 of 333: Modellbahnmuseum Mariazellerbahn
# processing entry 184 of 333: Erlauftaler Feuerwehrmuseum
# processing entry 185 of 333: Pielachtalbad Rabenstein an der Pielach
# processing entry 186 of 333: Steinschaler Naturgärten
# processing entry 187 of 333: Benedict-Randhartinger-Museum
# processing entry 188 of 333: Allwetterbad Scheibbs
# processing entry 189 of 333: Keramikmuseum Scheibbs
# processing entry 190 of 333: Landesausstellung 2015: Neubruck
# processing entry 191 of 333: Hammerherrenmuseum
# processing entry 192 of 333: Seebad
# processing entry 193 of 333: Freibad Mitterbach
# processing entry 194 of 333: Stift Seitenstetten
# processing entry 195 of 333: Aquacity
# processing entry 196 of 333: citysplash St. Pölten
# processing entry 197 of 333: Diözesanmuseum St. Pölten
# processing entry 198 of 333: Landesmuseum Niederösterreich
# processing entry 199 of 333: NXP Bowling
# processing entry 200 of 333: Rosenfellner Mühle
# processing entry 201 of 333: SPORT. ZENTRUM Niederoesterreich
# processing entry 202 of 333: Stadtmuseum St. Pölten
# processing entry 203 of 333: Weißer Zoo im Kameltheater
# processing entry 204 of 333: MostBirnHaus Ardagger
# processing entry 205 of 333: Urzeitmuseum
# processing entry 206 of 333: Eibl Jet
# processing entry 207 of 333: Naturschwimmbad Türnitz
# processing entry 208 of 333: Naturpark Ötscher-Tormäuer
# processing entry 209 of 333: Landesausstellung 2015: Wienerbruck
# processing entry 210 of 333: Wieselburger Badewelt
# processing entry 211 of 333: Erlebniswelt Mendlingtal
# processing entry 212 of 333: Freibad Neuhofen an der Ybbs
# processing entry 213 of 333: Freizeitzentrum Neumarkt an der Ybbs
# processing entry 214 of 333: Wanderparadies Hochkar
# processing entry 215 of 333: Skigebiet Königsberg
# processing entry 216 of 333: Natur- und Erlebnispark Buchenberg
# processing entry 217 of 333: Ostarrichi-Kulturhof
# processing entry 218 of 333: Museales Schaukraftwerk Schwellöd
# processing entry 219 of 333: 5e Museum – 5 Elemente im Rothschildschloss
# processing entry 220 of 333: Kletterwald im Naturpark Buchenberg
# processing entry 221 of 333: Ybbstaler Solebad
# processing entry 222 of 333: FeRRUM – welt des eisens
# processing entry 223 of 333: MOSTELLERIA – Die geheimnisvolle Welt der Mostbirne
# processing entry 224 of 333: Jagdschloss Mayerling
# processing entry 225 of 333: Tropfsteinhöhle
# processing entry 226 of 333: Arnulf Rainer Museum
# processing entry 227 of 333: Puppen- und Spielzeugmuseum
# processing entry 228 of 333: Badener Trabrennverein
# processing entry 229 of 333: Beethovenhaus „Haus der Neunten“
# processing entry 230 of 333: Kaiser-Franz-Josef-Museum
# processing entry 231 of 333: Kaiserhaus
# processing entry 232 of 333: Rollettmuseum
# processing entry 233 of 333: Römertherme Baden
# processing entry 234 of 333: Berndorfer Stilklassen
# processing entry 235 of 333: krupp stadt museum BERNDORF
# processing entry 236 of 333: MAGNA RACINO
# processing entry 237 of 333: Freibad der Marktgemeinde Gumpoldskirchen
# processing entry 238 of 333: Freigut Thallern
# processing entry 239 of 333: Gumpoldskirchner Weinbaumuseum
# processing entry 240 of 333: Seegrotte Hinterbrühl
# processing entry 241 of 333: Die Kletterei – Kletterzentrum
# processing entry 242 of 333: Essl Museum
# processing entry 243 of 333: Schlosspark Laxenburg
# processing entry 244 of 333: LEUM - Lichtmuseum & mehr
# processing entry 245 of 333: Minigolfclub Leobersdorf
# processing entry 246 of 333: Wellnessoase Leobersdorf
# processing entry 247 of 333: Kletterhalle Südstadt
# processing entry 248 of 333: Kartause Mauerbach
# processing entry 249 of 333: Museum Mödling – Thonetschlössl
# processing entry 250 of 333: Rocktopia – die Kletterhalle
# processing entry 251 of 333: Volkskundemuseum Mödling
# processing entry 252 of 333: Freizeitzentrum Perchtoldsdorf
# processing entry 253 of 333: Naturpark Sparbach
# processing entry 254 of 333: Stadtmuseum Traiskirchen
# processing entry 255 of 333: Farbie Kinderspielwelt
# processing entry 256 of 333: Vöslauer Mineralwasser AG
# processing entry 257 of 333: Stadtmuseum Bad Vöslau
# processing entry 258 of 333: Vöslauer Thermalbad
# processing entry 259 of 333: Glasmuseum „Die gläserne Burg“
# processing entry 260 of 333: Triestingtaler Heimatmuseum
# processing entry 261 of 333: Zisterzienserabtei Stift Heiligenkreuz
# processing entry 262 of 333: Fischauer Thermalbad
# processing entry 263 of 333: Burg Forchtenstein
# processing entry 264 of 333: Renner Museum für Zeitgeschichte
# processing entry 265 of 333: Waldbauernmuseum Gutenstein
# processing entry 266 of 333: Zinnfigurenwelt Katzelsdorf
# processing entry 267 of 333: Automobilmuseum
# processing entry 268 of 333: Freibad Aspang
# processing entry 269 of 333: Gauermann-Museum
# processing entry 270 of 333: Sessellift, Roller- u. Mountaincartbahn
# processing entry 271 of 333: Städtisches Museum
# processing entry 272 of 333: Waldbad Markt Piesting
# processing entry 273 of 333: Schlossbad Pitten
# processing entry 274 of 333: Rax-Seilbahn
# processing entry 275 of 333: Galerie und Atelier VOKA
# processing entry 276 of 333: Schneeberg Sesselbahn
# processing entry 277 of 333: Schneebergbahn
# processing entry 278 of 333: Schwimmbad Grünbach
# processing entry 279 of 333: MOBILEUM
# processing entry 280 of 333: Archäologisches Freilichtmuseum Schwarzenbach
# processing entry 281 of 333: Zau[:ber:]g Semmering
# processing entry 282 of 333: Hohe Wand Naturpark und Mautstraße
# processing entry 283 of 333: Familienskiland St. Corona
# processing entry 284 of 333: RAMSWIRT – schwerster Fleckviehzuchtstier
# processing entry 285 of 333: Sommerrodelbahn Alpine-Coaster
# processing entry 286 of 333: Wechsel-Semmering-Panoramaloipe
# processing entry 287 of 333: Burgbad Kirchschlag
# processing entry 288 of 333: Indoor Golf
# processing entry 289 of 333: Industrieviertelmuseum
# processing entry 290 of 333: Stadtmuseum Wiener Neustadt
# processing entry 291 of 333: Würflacher WellnessWelt
# processing entry 292 of 333: 21er Haus
# processing entry 293 of 333: Donauturm
# processing entry 294 of 333: Haus der Musik - Das Klangmuseum
# processing entry 295 of 333: Heeresgeschichtliches Museum
# processing entry 296 of 333: Josephinum - Sammlung der Medizinischen Universität
# processing entry 297 of 333: Kaiserliche Wagenburg
# processing entry 298 of 333: Madame Tussauds Wien
# processing entry 299 of 333: Monki Park
# processing entry 300 of 333: MS Kaiserin Elisabeth II
# processing entry 301 of 333: Museum des FK Austria Wien
# processing entry 302 of 333: Museum im Schottenstift
# processing entry 303 of 333: Österreichische Nationalbibliothek
# processing entry 304 of 333: Österreichisches Museum für Volkskunde
# processing entry 305 of 333: Porzellanmuseum im Augarten
# processing entry 306 of 333: Schlumberger Kellerwelten
# processing entry 307 of 333: SchokoMuseum
# processing entry 308 of 333: Schönbrunner Panoramabahn
# processing entry 309 of 333: Secession
# processing entry 310 of 333: Sigmund Freud Museum
# processing entry 311 of 333: Spanische Hofreitschule
# processing entry 312 of 333: Time Travel
# processing entry 313 of 333: UNO - Vereinte Nationen
# processing entry 314 of 333: Unteres Belvedere
# processing entry 315 of 333: Verkehrsmuseum der Wiener Linien
# processing entry 316 of 333: Vienna Ring Tram
# processing entry 317 of 333: VISITAIR Center – Faszination Flughafen
# processing entry 318 of 333: Wiener Riesenrad
# processing entry 319 of 333: Winterpalais des Prinzen Eugen von Savoyen
# processing entry 320 of 333: Wüstenhaus Schönbrunn
# processing entry 321 of 333: Schloss Esterházy
# processing entry 322 of 333: Reptilien Zoo
# processing entry 323 of 333: Freilichtmuseum Ensemble Gerersdorf
# processing entry 324 of 333: Schloss Halbturn
# processing entry 325 of 333: Schloss Lackenbach
# processing entry 326 of 333: Landtechnikmuseum Burgenland
# processing entry 327 of 333: Museum Arbeitswelt
# processing entry 328 of 333: bellabayer – das Gartenatelier
# processing entry 329 of 333: oekopark Hartberg
# processing entry 330 of 333: Stadtmuseum Hartberg
# processing entry 331 of 333: Lipizzanergestüt Piber
# processing entry 332 of 333: Mariazeller Bürgeralpe
# generate final upload process ...
# processcount: 1 process-queue: 0  collected so far: 328
# waiting for upload-process <Process(Process-1, started)> to finish ...
# 328

# %% [markdown]
# Now, we want to include the image of the entry. We have to perform this step in a second run, since with the CouchDB interface in Python, the document has to already exist, when an attachment is added to it.

# %%
couchdbserver = couchdb.Server(couchdbUrl)
couchdbdb = couchdbserver['noecard']

for i, entry in enumerate(collectedDocs):
    print("Retrieving {}: {}".format(i, entry['title']))
    currentDoc = couchdbdb.get(entry['title'])
    if currentDoc != None and currentDoc['imageUrl'] != '':
        response = requests.get(currentDoc['imageUrl'])
        storeName = currentDoc['title']+".jpg"
        couchdbdb.put_attachment(currentDoc, response.content, filename=storeName, content_type='image/jpeg')
# Out:
# Retrieving 0: Stift Altenburg
# Retrieving 1: BÄRENWALD
# Retrieving 2: Hammerschmiede Kamp
# Retrieving 3: Mohndorf Armschlag
# Retrieving 4: Schnaps-Glas-Museum Echsenbach
# Retrieving 5: Krahuletz-Museum
# Retrieving 6: Nostalgiewelt Eggenburg
# Retrieving 7: Perlmuttdrechslerei
# Retrieving 8: NÖ Falknerei- und Greifvogelzentrum
# Retrieving 9: Wirtex – Älteste Frottierweberei
# Retrieving 10: Naturpark Geras
# Retrieving 11: Stift Geras
# Retrieving 12: Naturpark Blockheide
# Retrieving 13: Sole-Felsen-Bad
# Retrieving 14: Waldviertelbahn
# Retrieving 15: Schloss Grafenegg
# Retrieving 16: SONNENWELT
# Retrieving 17: Nationalpark Thayatal
# Retrieving 18: Käsemacherwelt
# Retrieving 19: Naturpark Heidenreichsteiner Moor
# Retrieving 20: Museen der Stadt Horn Höbarth- und Madermuseum
# Retrieving 21: Kindererlebniswelt MOKE
# Retrieving 22: Sport- und Erlebnisbad Gars am Kamp
# Retrieving 23: Zeitbrücke-Museum
# Retrieving 24: Schidorf Kirchbach
# Retrieving 25: Miniaturgolfplatz
# Retrieving 26: Freizeitmuseum Langau
# Retrieving 27: Heimatmuseum Langenlois
# Retrieving 28: LOISIUM- WeinErlebnisWelt
# Retrieving 29: Energiewelt „SIRIUS“
# Retrieving 30: Golfclub Herrensee
# Retrieving 31: Amethyst Welt Maissau
# Retrieving 32: Edelsteinhaus Maissau
# Retrieving 33: Märchenausstellung
# Retrieving 34: Waldviertler Mohnhof
# Retrieving 35: Freibad Mandlgupf
# Retrieving 36: Kunstglasbläserei
# Retrieving 37: Schloss Pöggstall
# Retrieving 38: Hanfdorf Reingers
# Retrieving 39: Museum Retz und Südmährische Galerie
# Retrieving 40: Bahnerlebnis Reblaus Express
# Retrieving 41: Windmühle Retz
# Retrieving 42: Whisky-Erlebniswelt, Destillerie Haider
# Retrieving 43: Renaissanceschloss Greillenstein
# Retrieving 44: Kittenberger Erlebnisgärten
# Retrieving 45: ANWO Schaugarten
# Retrieving 46: Österreichisches Freimaurermuseum
# Retrieving 47: Das Kunstmuseum Waldviertel
# Retrieving 48: Schätze der Vergangenheit
# Retrieving 49: UnterWasserReich
# Retrieving 50: Waldviertler Schuhwerkstatt
# Retrieving 51: Waldviertler Erdäpfelwelt
# Retrieving 52: Kloster-Schul-Werkstätten & Museum Schönbach
# Retrieving 53: Straußenland Gärtner
# Retrieving 54: Freilichtmuseum Germanisches Gehöft Elsarn
# Retrieving 55: Fassbinderei- und Weinbaumuseum
# Retrieving 56: Schatzkammer der Basilika
# Retrieving 57: Kräuterpfarrer-Weidinger-Zentrum
# Retrieving 58: Ruine Kollmitz
# Retrieving 59: Thayatal Vitalbad
# Retrieving 60: Uhrenmuseum Karlstein
# Retrieving 61: Ausstellungszentrum Josef Elter
# Retrieving 62: Waldrapp Voliere
# Retrieving 63: Sonnenuhren-Ausstellung Jindra
# Retrieving 64: Brauerei im Brauhotel Weitra
# Retrieving 65: Schloss Weitra
# Retrieving 66: Hallenbad Yspertal
# Retrieving 67: Zwettler Dämmerschoppen
# Retrieving 68: SONNENTOR Erlebnis
# Retrieving 69: Stadtmuseum Zwettl
# Retrieving 70: Zisterzienserstift Zwettl
# Retrieving 71: Kinderparadies Wirtshaus zur Minidampfbahn
# Retrieving 72: ZwettlBad
# Retrieving 73: Traktorium Drasenhofen
# Retrieving 74: Erlebnis-Freibad Eggenburg
# Retrieving 75: NostalgieExpress Leiser Berge
# Retrieving 76: Erstes Österreichisches Küchenmuseum und Greisslereimuseum
# Retrieving 77: Nonseum
# Retrieving 78: Schloss Jedenspeigen
# Retrieving 79: Der Heldenberg
# Retrieving 80: LEMU - LANGENZERSDORF MUSEUM
# Retrieving 81: Schloss Mailberg
# Retrieving 82: Michelstettner Schule
# Retrieving 83: MAMUZ MUSEUM Mistelbach
# Retrieving 84: Zayataler Schienentaxi
# Retrieving 85: Museumsdorf Niedersulz
# Retrieving 86: Wehrturm
# Retrieving 87: Steinzeitkeller
# Retrieving 88: Oldtimermuseum Poysdorf
# Retrieving 89: Vino Versum
# Retrieving 90: Pulkauer Blutkirche
# Retrieving 91: KLEINHAUS – Bio Weinbau Killmeyer
# Retrieving 92: Fahrradmuseum Retz
# Retrieving 93: Retzer Erlebniskeller
# Retrieving 94: Perlen- und Fossilienwelt Weinviertel
# Retrieving 95: STILLFRIED – Zentrum der Urzeit
# Retrieving 96: Kutschenmuseum Laa
# Retrieving 97: Liechtenstein-Schloss Wilfersdorf
# Retrieving 98: Kunsteisbahn Wolkersdorf
# Retrieving 99: Kletterhalle Nordwandklettern
# Retrieving 100: Sommerbad Wolkersdorf
# Retrieving 101: MAMUZ Schloss Asparn an der Zaya
# Retrieving 102: Freibad Absdorf
# Retrieving 103: Schloss Artstetten
# Retrieving 104: Museum Carnuntinum
# Retrieving 105: Kuenringer Freibad Dürnstein
# Retrieving 106: Schloss Eckartsau
# Retrieving 107: ERLAUF ERINNERT Museum der Friedensgemeinde Erlauf
# Retrieving 108: Erlebnispark Gänserndorf
# Retrieving 109: Benediktinerstift Göttweig
# Retrieving 110: Bergbad
# Retrieving 111: Stadtführung Mittelalterstadt
# Retrieving 112: Aquapark Herzogenburg
# Retrieving 113: Stift Herzogenburg
# Retrieving 114: Happyland
# Retrieving 115: Stift Klosterneuburg
# Retrieving 116: Bahnengolfclub Wachau
# Retrieving 117: BRANDNER Schiffahrt GmbH
# Retrieving 118: Gozzoburg
# Retrieving 119: Museum Krems
# Retrieving 120: Weinerlebnis „Sandgrube 13 wein.sinn“ Winzer Krems
# Retrieving 121: Wachaubahn
# Retrieving 122: Zeit Kunst Niederösterreich
# Retrieving 123: Parkbad Königstetten
# Retrieving 124: Landtechnikmuseum im Europaschloss Leiben
# Retrieving 125: VillaVinum
# Retrieving 126: Schloss Marchegg
# Retrieving 127: museum gugging
# Retrieving 128: Römermuseum Mautern
# Retrieving 129: DDSG Blue Danube Schiffahrt
# Retrieving 130: Benediktinerstift Melk
# Retrieving 131: Bäckereimuseum
# Retrieving 132: museumORTH an der Donau
# Retrieving 133: schlossORTH Nationalpark-Zentrum
# Retrieving 134: Archäologischer Park Carnuntum
# Retrieving 135: Oskar-Kokoschka-Dokumentation
# Retrieving 136: Haydn-Geburtshaus Rohrau
# Retrieving 137: Schloss Rohrau – Graf Harrach’sche Familiensammlung
# Retrieving 138: Pleyel-Museum
# Retrieving 139: Schloss Hof
# Retrieving 140: Schloss Niederweiden
# Retrieving 141: Eisenbahnmuseum Schwechat
# Retrieving 142: Parkbad
# Retrieving 143: Autofrei unterwegs in der Wachau
# Retrieving 144: Schifffahrtsmuseum
# Retrieving 145: Forum Frohner
# Retrieving 146: Karikaturmuseum Krems
# Retrieving 147: Kunsthalle Krems
# Retrieving 148: Eisenbahnmuseum Strasshof
# Retrieving 149: Aubad der Stadt Tulln
# Retrieving 150: DIE GARTEN TULLN – Naturgarten Erlebniswelt Niederösterreich
# Retrieving 151: Egon Schiele Museum
# Retrieving 152: Donau Splash
# Retrieving 153: Kunsteisbahn der Stadt Tulln
# Retrieving 154: MS Stadt Wien - Nostalgieschiff
# Retrieving 155: Römermuseum Tulln
# Retrieving 156: Wachaumuseum
# Retrieving 157: Donaukraftwerk
# Retrieving 158: Annaberger Liftbetriebe
# Retrieving 159: Wienerwaldmuseum und Lebendiges Handwerk
# Retrieving 160: Freibad Frankenfels
# Retrieving 161: Bergbauernmuseum Hausstein
# Retrieving 162: Landesausstellung 2015: Frankenfels – Laubenbachmühle
# Retrieving 163: Nixhöhle
# Retrieving 164: Bruckners Bierwelt
# Retrieving 165: Hallenbad und Sauna Gaming
# Retrieving 166: Kartause Gaming
# Retrieving 167: Ötscher Tropfsteinhöhle
# Retrieving 168: Ötscherland Freibad Gaming
# Retrieving 169: Tierpark Stadt Haag
# Retrieving 170: Abenteuerland Pielachtal
# Retrieving 171: PIELACHTALER sehnsucht
# Retrieving 172: Voralpenbad Hohenberg
# Retrieving 173: Kornkreismuseum
# Retrieving 174: Ötscherlifte
# Retrieving 175: Sessellift Lilienfeld Muckenkogel
# Retrieving 176: Stift Lilienfeld
# Retrieving 177: Renaissanceschloss Schallaburg
# Retrieving 178: Bergbahnen Mitterbach
# Retrieving 179: Freibad Neulengbach
# Retrieving 180: World of STYX
# Retrieving 181: HAUBIVERSUM – „Die Backerlebniswelt“
# Retrieving 182: Erlebnisfreibad Kirchberg an der Pielach
# Retrieving 183: Modellbahnmuseum Mariazellerbahn
# Retrieving 184: Erlauftaler Feuerwehrmuseum
# Retrieving 185: Pielachtalbad Rabenstein an der Pielach
# Retrieving 186: Steinschaler Naturgärten
# Retrieving 187: Benedict-Randhartinger-Museum
# Retrieving 188: Allwetterbad Scheibbs
# Retrieving 189: Keramikmuseum Scheibbs
# Retrieving 190: Landesausstellung 2015: Neubruck
# Retrieving 191: Hammerherrenmuseum
# Retrieving 192: Seebad
# Retrieving 193: Freibad Mitterbach
# Retrieving 194: Stift Seitenstetten
# Retrieving 195: Aquacity
# Retrieving 196: citysplash St. Pölten
# Retrieving 197: Diözesanmuseum St. Pölten
# Retrieving 198: Landesmuseum Niederösterreich
# Retrieving 199: NXP Bowling
# Retrieving 200: Rosenfellner Mühle
# Retrieving 201: SPORT. ZENTRUM Niederoesterreich
# Retrieving 202: Stadtmuseum St. Pölten
# Retrieving 203: Weißer Zoo im Kameltheater
# Retrieving 204: MostBirnHaus Ardagger
# Retrieving 205: Urzeitmuseum
# Retrieving 206: Eibl Jet
# Retrieving 207: Naturschwimmbad Türnitz
# Retrieving 208: Naturpark Ötscher-Tormäuer
# Retrieving 209: Landesausstellung 2015: Wienerbruck
# Retrieving 210: Wieselburger Badewelt
# Retrieving 211: Erlebniswelt Mendlingtal
# Retrieving 212: Freibad Neuhofen an der Ybbs
# Retrieving 213: Freizeitzentrum Neumarkt an der Ybbs
# Retrieving 214: Wanderparadies Hochkar
# Retrieving 215: Skigebiet Königsberg
# Retrieving 216: Natur- und Erlebnispark Buchenberg
# Retrieving 217: Ostarrichi-Kulturhof
# Retrieving 218: Museales Schaukraftwerk Schwellöd
# Retrieving 219: 5e Museum – 5 Elemente im Rothschildschloss
# Retrieving 220: Kletterwald im Naturpark Buchenberg
# Retrieving 221: Ybbstaler Solebad
# Retrieving 222: FeRRUM – welt des eisens
# Retrieving 223: MOSTELLERIA – Die geheimnisvolle Welt der Mostbirne
# Retrieving 224: Jagdschloss Mayerling
# Retrieving 225: Tropfsteinhöhle
# Retrieving 226: Arnulf Rainer Museum
# Retrieving 227: Puppen- und Spielzeugmuseum
# Retrieving 228: Badener Trabrennverein
# Retrieving 229: Beethovenhaus „Haus der Neunten“
# Retrieving 230: Kaiser-Franz-Josef-Museum
# Retrieving 231: Kaiserhaus
# Retrieving 232: Rollettmuseum
# Retrieving 233: Römertherme Baden
# Retrieving 234: Berndorfer Stilklassen
# Retrieving 235: krupp stadt museum BERNDORF
# Retrieving 236: MAGNA RACINO
# Retrieving 237: Freibad der Marktgemeinde Gumpoldskirchen
# Retrieving 238: Freigut Thallern
# Retrieving 239: Gumpoldskirchner Weinbaumuseum
# Retrieving 240: Seegrotte Hinterbrühl
# Retrieving 241: Die Kletterei – Kletterzentrum
# Retrieving 242: Essl Museum
# Retrieving 243: Schlosspark Laxenburg
# Retrieving 244: LEUM - Lichtmuseum & mehr
# Retrieving 245: Minigolfclub Leobersdorf
# Retrieving 246: Wellnessoase Leobersdorf
# Retrieving 247: Kletterhalle Südstadt
# Retrieving 248: Kartause Mauerbach
# Retrieving 249: Museum Mödling – Thonetschlössl
# Retrieving 250: Rocktopia – die Kletterhalle
# Retrieving 251: Volkskundemuseum Mödling
# Retrieving 252: Freizeitzentrum Perchtoldsdorf
# Retrieving 253: Naturpark Sparbach
# Retrieving 254: Stadtmuseum Traiskirchen
# Retrieving 255: Farbie Kinderspielwelt
# Retrieving 256: Vöslauer Mineralwasser AG
# Retrieving 257: Stadtmuseum Bad Vöslau
# Retrieving 258: Vöslauer Thermalbad
# Retrieving 259: Glasmuseum „Die gläserne Burg“
# Retrieving 260: Triestingtaler Heimatmuseum
# Retrieving 261: Zisterzienserabtei Stift Heiligenkreuz
# Retrieving 262: Fischauer Thermalbad
# Retrieving 263: Burg Forchtenstein
# Retrieving 264: Renner Museum für Zeitgeschichte
# Retrieving 265: Waldbauernmuseum Gutenstein
# Retrieving 266: Zinnfigurenwelt Katzelsdorf
# Retrieving 267: Automobilmuseum
# Retrieving 268: Freibad Aspang
# Retrieving 269: Gauermann-Museum
# Retrieving 270: Sessellift, Roller- u. Mountaincartbahn
# Retrieving 271: Städtisches Museum
# Retrieving 272: Waldbad Markt Piesting
# Retrieving 273: Schlossbad Pitten
# Retrieving 274: Rax-Seilbahn
# Retrieving 275: Galerie und Atelier VOKA
# Retrieving 276: Schneeberg Sesselbahn
# Retrieving 277: Schneebergbahn
# Retrieving 278: Schwimmbad Grünbach
# Retrieving 279: MOBILEUM
# Retrieving 280: Archäologisches Freilichtmuseum Schwarzenbach
# Retrieving 281: Zau[:ber:]g Semmering
# Retrieving 282: Hohe Wand Naturpark und Mautstraße
# Retrieving 283: Familienskiland St. Corona
# Retrieving 284: RAMSWIRT – schwerster Fleckviehzuchtstier
# Retrieving 285: Sommerrodelbahn Alpine-Coaster
# Retrieving 286: Wechsel-Semmering-Panoramaloipe
# Retrieving 287: Burgbad Kirchschlag
# Retrieving 288: Indoor Golf
# Retrieving 289: Industrieviertelmuseum
# Retrieving 290: Stadtmuseum Wiener Neustadt
# Retrieving 291: Würflacher WellnessWelt
# Retrieving 292: 21er Haus
# Retrieving 293: Donauturm
# Retrieving 294: Haus der Musik - Das Klangmuseum
# Retrieving 295: Heeresgeschichtliches Museum
# Retrieving 296: Josephinum - Sammlung der Medizinischen Universität
# Retrieving 297: Kaiserliche Wagenburg
# Retrieving 298: Madame Tussauds Wien
# Retrieving 299: Monki Park
# Retrieving 300: MS Kaiserin Elisabeth II
# Retrieving 301: Museum des FK Austria Wien
# Retrieving 302: Museum im Schottenstift
# Retrieving 303: Österreichische Nationalbibliothek
# Retrieving 304: Österreichisches Museum für Volkskunde
# Retrieving 305: Porzellanmuseum im Augarten
# Retrieving 306: Schlumberger Kellerwelten
# Retrieving 307: SchokoMuseum
# Retrieving 308: Schönbrunner Panoramabahn
# Retrieving 309: Secession
# Retrieving 310: Sigmund Freud Museum
# Retrieving 311: Spanische Hofreitschule
# Retrieving 312: Time Travel
# Retrieving 313: UNO - Vereinte Nationen
# Retrieving 314: Unteres Belvedere
# Retrieving 315: Verkehrsmuseum der Wiener Linien
# Retrieving 316: Vienna Ring Tram
# Retrieving 317: VISITAIR Center – Faszination Flughafen
# Retrieving 318: Wiener Riesenrad
# Retrieving 319: Winterpalais des Prinzen Eugen von Savoyen
# Retrieving 320: Wüstenhaus Schönbrunn
# Retrieving 321: Schloss Esterházy
# Retrieving 322: Reptilien Zoo
# Retrieving 323: Freilichtmuseum Ensemble Gerersdorf
# Retrieving 324: Schloss Halbturn
# Retrieving 325: Schloss Lackenbach
# Retrieving 326: Landtechnikmuseum Burgenland
# Retrieving 327: Museum Arbeitswelt
# Retrieving 328: bellabayer – das Gartenatelier
# Retrieving 329: oekopark Hartberg
# Retrieving 330: Stadtmuseum Hartberg
# Retrieving 331: Lipizzanergestüt Piber
# Retrieving 332: Mariazeller Bürgeralpe
